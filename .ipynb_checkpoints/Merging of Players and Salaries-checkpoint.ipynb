# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datadavis-nba-salaries_players.csv')
df.head(3)
# Out:
#          _id       birthDate          birthPlace  career_AST career_FG%  \
# 0  abdelal01   June 24, 1968        Cairo, Egypt         0.3       50.2
# 1  abdulza01   April 7, 1946  Brooklyn, New York         1.2       42.8
# 2  abdulka01  April 16, 1947  New York, New York         3.6       55.9
#
#   career_FG3% career_FT%  career_G career_PER  career_PTS  ...    draft_pick  \
# 0         0.0       70.1       256       13.0         5.7  ...  25th overall
# 1         NaN       72.8       505       15.1         9.0  ...   5th overall
# 2         5.6       72.1      1560       24.6        24.6  ...   1st overall
#
#   draft_round              draft_team draft_year height  \
# 0   1st round  Portland Trail Blazers       1990   6-10
# 1   1st round       Cincinnati Royals       1968    6-9
# 2   1st round         Milwaukee Bucks       1969    7-2
#
#                              highSchool                 name  \
# 0  Bloomfield in Bloomfield, New Jersey       Alaa Abdelnaby
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             _id          birthDate                      birthPlace  \
# 0     abdelal01      June 24, 1968                    Cairo, Egypt
# 1     abdulza01      April 7, 1946              Brooklyn, New York
# 2     abdulka01     April 16, 1947              New York, New York
# 3     abdulma02      March 9, 1969           Gulfport, Mississippi
# 4     abdulta01   November 3, 1974          Maisons Alfort, France
# ...         ...                ...                             ...
# 4680  zizican01    January 4, 1997                  Split, Croatia
# 4681   zoetji01  December 20, 1953                Uxbridge, Canada
# 4682   zopfbi01       June 7, 1948                             NaN
# 4683  zubaciv01     March 18, 1997  Mostar, Bosnia and Herzegovina
# 4684  zunicma01  December 19, 1919            Renton, Pennsylvania
#
#       career_AST career_FG% career_FG3% career_FT%  career_G career_PER  \
# ...

# %%
df.shape
# Out:
# (4685, 24)

# %%
# the second data set for salaries
df1 = pd.read_csv('datadavis-nba-salaries_salaries_1985to2018.csv')
df1.head()
# Out:
#   league  player_id  salary   season  season_end  season_start  \
# 0    NBA  abdelal01  395000  1990-91        1991          1990
# 1    NBA  abdelal01  494000  1991-92        1992          1991
# 2    NBA  abdelal01  500000  1992-93        1993          1992
# 3    NBA  abdelal01  805000  1993-94        1994          1993
# 4    NBA  abdelal01  650000  1994-95        1995          1994
#
#                      team
# 0  Portland Trail Blazers
# 1  Portland Trail Blazers
# 2          Boston Celtics
# 3          Boston Celtics
# 4        Sacramento Kings

# %%
# mergeing the two data set
# pd.merge(a, b, left_on =, right_on =)
df2 =pd.merge(df, df1, left_on = '_id', right_on = 'player_id')
df2.head(3)
# Out:
#          _id      birthDate    birthPlace  career_AST career_FG% career_FG3%  \
# 0  abdelal01  June 24, 1968  Cairo, Egypt         0.3       50.2         0.0
# 1  abdelal01  June 24, 1968  Cairo, Egypt         0.3       50.2         0.0
# 2  abdelal01  June 24, 1968  Cairo, Egypt         0.3       50.2         0.0
#
#   career_FT%  career_G career_PER  career_PTS  ...       position shoots  \
# 0       70.1       256       13.0         5.7  ...  Power Forward  Right
# 1       70.1       256       13.0         5.7  ...  Power Forward  Right
# 2       70.1       256       13.0         5.7  ...  Power Forward  Right
#
#   weight league  player_id  salary   season season_end season_start  \
# 0  240lb    NBA  abdelal01  395000  1990-91       1991         1990
# 1  240lb    NBA  abdelal01  494000  1991-92       1992         1991
# 2  240lb    NBA  abdelal01  500000  1992-93       1993         1992
#
#                      team
# 0  Portland Trail Blazers
# 1  Portland Trail Blazers
# ...

# %%
df2.dtypes
# Out:
# _id              object
# birthDate        object
# birthPlace       object
# career_AST      float64
# career_FG%       object
# career_FG3%      object
# career_FT%       object
# career_G          int64
# career_PER       object
# career_PTS      float64
# career_TRB       object
# career_WS        object
# career_eFG%      object
# college          object
# draft_pick       object
# draft_round      object
# draft_team       object
# draft_year       object
# height           object
# highSchool       object
# name             object
# position         object
# shoots           object
# weight           object
# league           object
# player_id        object
# salary            int64
# season           object
# season_end        int64
# season_start      int64
# team             object
# dtype: object

# %%
#to check for null_values in both data sets
null_cols = df2.isnull()
null_cols
# Out:
#          _id  birthDate  birthPlace  career_AST  career_FG%  career_FG3%  \
# 0      False      False       False       False       False        False
# 1      False      False       False       False       False        False
# 2      False      False       False       False       False        False
# 3      False      False       False       False       False        False
# 4      False      False       False       False       False        False
# ...      ...        ...         ...         ...         ...          ...
# 14158  False      False       False       False       False        False
# 14159  False      False       False       False       False        False
# 14160  False      False       False       False       False        False
# 14161  False      False       False       False       False        False
# 14162  False      False       False       False       False        False
#
#        career_FT%  career_G  career_PER  career_PTS  ...  position  shoots  \
# ...

# %%
#null_displ = data[(data['displ'].isnull()==True)]
#null_displ = null_displ[['year', 'make', 'model', 'trany', 'drive','fuelType','cylinders', 'displ']]
#null_displ

null_display = df2[(df2['team'].isnull()==True)]
null_display
# Out:
#              _id        birthDate           birthPlace  career_AST career_FG%  \
# 1419   bosweto01  October 2, 1953  Montgomery, Alabama         1.6       53.3
# 2200   cartwbi01    July 30, 1957     Lodi, California         1.4       52.5
# 13260  webstma01   April 13, 1952  Baltimore, Maryland         1.2       48.8
# 13802  williro02      May 5, 1961       Houston, Texas         5.4       43.9
#
#       career_FG3% career_FT%  career_G career_PER  career_PTS  ...  \
# 1419         54.5       72.4       366       13.7         7.7  ...
# 2200          0.0       77.1       963       15.2        13.2  ...
# 13260        28.6       62.1       617       13.8         7.0  ...
# 13802        27.4       78.9       153       12.2         8.6  ...
#
#             position shoots weight league  player_id  salary   season  \
# 1419   Power Forward  Right  220lb    NBA  bosweto01   65000  1984-85
# 2200          Center  Right  245lb    NBA  cartwbi01  600000  1984-85
# ...
