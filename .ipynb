# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/mehrib5wxi5mqovwtgyt3hpzdnllyp')

# %%
df
# Out:
#       league  player_id   salary   season  season_end  season_start  \
# 0        NBA  abdelal01   395000  1990-91        1991          1990
# 1        NBA  abdelal01   494000  1991-92        1992          1991
# 2        NBA  abdelal01   500000  1992-93        1993          1992
# 3        NBA  abdelal01   805000  1993-94        1994          1993
# 4        NBA  abdelal01   650000  1994-95        1995          1994
# ...      ...        ...      ...      ...         ...           ...
# 14158    NBA  zipsepa01   750000  2016-17        2017          2016
# 14159    NBA  zipsepa01  1312611  2017-18        2018          2017
# 14160    NBA  zizican01  1645200  2017-18        2018          2017
# 14161    NBA  zubaciv01  1034956  2016-17        2017          2016
# 14162    NBA  zubaciv01  1312611  2017-18        2018          2017
#
#                          team
# 0      Portland Trail Blazers
# 1      Portland Trail Blazers
# 2              Boston Celtics
# ...

# %%
df.shape
# Out:
# (14163, 7)

# %%
df.dtypes
# Out:
# league          object
# player_id       object
# salary           int64
# season          object
# season_end       int64
# season_start     int64
# team            object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of       league  player_id   salary   season  season_end  season_start  \
# 0        NBA  abdelal01   395000  1990-91        1991          1990
# 1        NBA  abdelal01   494000  1991-92        1992          1991
# 2        NBA  abdelal01   500000  1992-93        1993          1992
# 3        NBA  abdelal01   805000  1993-94        1994          1993
# 4        NBA  abdelal01   650000  1994-95        1995          1994
# ...      ...        ...      ...      ...         ...           ...
# 14158    NBA  zipsepa01   750000  2016-17        2017          2016
# 14159    NBA  zipsepa01  1312611  2017-18        2018          2017
# 14160    NBA  zizican01  1645200  2017-18        2018          2017
# 14161    NBA  zubaciv01  1034956  2016-17        2017          2016
# 14162    NBA  zubaciv01  1312611  2017-18        2018          2017
#
#                          team
# 0      Portland Trail Blazers
# 1      Portland Trail Blazers
# ...

# %%
# Investigating if there is any missing value in the columns
null_cols = df.isnull().sum()
null_cols
# Out:
# league          0
# player_id       0
# salary          0
# season          0
# season_end      0
# season_start    0
# team            4
# dtype: int64

# %%
df.columns
# Out:
# Index(['league', 'player_id', 'salary', 'season', 'season_end', 'season_start',
#        'team'],
#       dtype='object')

# %%
# Let's investigate the missing value in column 'team' by subsetting the data set and looking at 'Team where the null is and just the columns
null_display = df[(df['team'].isnull()==True)]
null_display = null_display[['league', 'player_id', 'salary', 'season', 'season_end', 'season_start','team']]
null_display
# Out:
#       league  player_id  salary   season  season_end  season_start team
# 1419     NBA  bosweto01   65000  1984-85        1985          1984  NaN
# 2200     NBA  cartwbi01  600000  1984-85        1985          1984  NaN
# 13260    NBA  webstma01  450000  1984-85        1985          1984  NaN
# 13802    NBA  williro02  120000  1984-85        1985          1984  NaN

# %%
# filling the missing values in'team' column with zeros
df['team'] = df[['team']].fillna(0)

df['team']
# Out:
# 0        Portland Trail Blazers
# 1        Portland Trail Blazers
# 2                Boston Celtics
# 3                Boston Celtics
# 4              Sacramento Kings
#                   ...
# 14158             Chicago Bulls
# 14159             Chicago Bulls
# 14160       Cleveland Cavaliers
# 14161        Los Angeles Lakers
# 14162        Los Angeles Lakers
# Name: team, Length: 14163, dtype: object

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# league          0
# player_id       0
# salary          0
# season          0
# season_end      0
# season_start    0
# team            0
# dtype: int64

# %%
df.dtypes
# Out:
# league          object
# player_id       object
# salary           int64
# season          object
# season_end       int64
# season_start     int64
# team            object
# dtype: object

# %%
#To bring out distinct values from all column
df['team'].value_counts().keys()
# Out:
# Index([                 'Dallas Mavericks',
#                       'Philadelphia 76ers',
#                             'Phoenix Suns',
#                          'Houston Rockets',
#                     'Los Angeles Clippers',
#                           'Boston Celtics',
#                          'New York Knicks',
#                            'Chicago Bulls',
#                            'Atlanta Hawks',
#                    'Golden State Warriors',
#                          'Milwaukee Bucks',
#                      'Cleveland Cavaliers',
#                           'Denver Nuggets',
#                        'San Antonio Spurs',
#                   'Portland Trail Blazers',
#                           'Indiana Pacers',
#                         'Sacramento Kings',
#                          'Detroit Pistons',
#                       'Los Angeles Lakers',
#                            'Orlando Magic',
#                                'Utah Jazz',
# ...

# %%
# discus with team members if to drop the column or fill it up, but not with zero

# %%
df1 = pd.read_csv('datadavis-nba-salaries_salaries_1985to2018.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-c5f0af02e7ad> in <module>
# ----> 1 df1 = pd.read_csv('datadavis-nba-salaries_salaries_1985to2018.csv')
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
